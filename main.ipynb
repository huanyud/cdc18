# %%
import numpy as np
import itertools
import math
import heapq
import time
import functools
import gurobi

np.random.seed(1)
np.set_printoptions(precision=4)

# %%
ifPrintPlan = False
runGAMS = False
runGetLowerBound = False
runOur_oneStage = False
runOur_twoStage = False
runOur_oneStage_random = False
runOur_twoStage_random = False
runRoyset2 = True
runRoyset3 = False
runDp = False
runMyopic = False
runBrute = False

# %% [markdown]
# ## Generate Model

# %%
def generateModel(locN, stageN, isPrintModel=True):
    # Generate the prior distribution vector
    priorVec = np.random.random(locN)
    priorVec /= priorVec.sum()
    if isPrintModel:
        print('The prior probability vector is:\n' + str(priorVec) + '\n')

    # Generate the Markov transition probability matrix (left stochastic matrix; each column sums up to one)
    tranProbMat = np.random.rand(locN, locN)
    tranProbMat /= tranProbMat.sum(axis=0)[None,:]
    if isPrintModel:
        print('The Markov transition probability matrix (x=Px) is:\n' + str(tranProbMat) + '\n')

    # Generate the probability vector of successful detections (between 0.5 to 1.0)
    detectVec = 1 - 0.5 * np.random.random(locN)
    if isPrintModel:
        print('The probability vector of successful detections is:\n' + str(detectVec) + '\n')

    # Compute the probability vector of missed detections
    missVec = 1 - detectVec
    if isPrintModel:
        print('The probability vector of failed detections is:\n' + str(missVec) + '\n')
    
    # Return model
    return priorVec, tranProbMat, detectVec, missVec

# %%
# agentN - number of agents
agentN = 10
# locN - number of locations
locN = 100
# stageN - number of stages
stageN = 15

[priorVec, tranProbMat, detectVec, missVec] = generateModel(locN, stageN, isPrintModel=False)

# %% [markdown]
# ## Utility Functions

# %%
def computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec):
    vec = np.copy(priorVec)
    for s in range(stageN):
        vec = tranProbMat.dot(np.multiply(np.power(missVec, actionVec[s]), vec))
    return sum(vec)

# %%
def getPossibleActions(locN, agentN):
    if locN == 1:
        yield [agentN]
    else:
        for i in range(agentN + 1):
            for j in getPossibleActions(locN - 1, agentN - i):
                yield [i] + j

# %% [markdown]
# ## Write GAMS Model

# %%
def writeGamsModel(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec):
    # Open file
    f = open('GAMS_file', 'w')
    
    # Write sets
    f.write('Set k /1*' + str(locN) + '/;\n')
    f.write('Alias (k,i,j);\n\n')
    f.write('Set t /1*' + str(stageN) + '/;\n')
    f.write('Alias (t,s);\n')
    f.write('Sets\n')
    f.write('\ttb(t) base period\n')
    f.write('\ttn(t) non-base period\n')
    f.write('\ttt(t) terminal period;\n')
    f.write('tb(t) = (ord(t) = 1);\n')
    f.write('tn(t) = (ord(t) > 1);\n')
    f.write('tt(t) = (ord(t) = card(t));\n\n')
    
    # Write parameters
    f.write('Parameters\n')
    f.write('\tM /' + str(agentN) + '/\n')
    f.write('\tprior(k)\n')
    for k in range(locN):
        if k == 0:
            f.write('\t/ ' + str(k+1) + '=' + str(priorVec[k]) + ',\n')
        elif k == locN - 1:
            f.write('\t  ' + str(k+1) + '=' + str(priorVec[k]) + ' /\n')
        else:
            f.write('\t  ' + str(k+1) + '=' + str(priorVec[k]) + ',\n')
    f.write('\tmiss(k)\n')
    for k in range(locN):
        if k == 0:
            f.write('\t/ ' + str(k+1) + '=' + str(missVec[k]) + ',\n')
        elif k == locN - 1:
            f.write('\t  ' + str(k+1) + '=' + str(missVec[k]) + ' /\n')
        else:
            f.write('\t  ' + str(k+1) + '=' + str(missVec[k]) + ',\n')
    f.write('\tP(i,j)\n')
    for i in range(locN):
        for j in range(locN):
            if i == 0 and j == 0:
                f.write('\t/ ' + str(i+1) + '.' + str(j+1) + '=' + str(tranProbMat[i][j]) + ',\n')
            elif i == locN-1 and j == locN-1:
                f.write('\t  ' + str(i+1) + '.' + str(j+1) + '=' + str(tranProbMat[i][j]) + ' /;\n')
            else:
                f.write('\t  ' + str(i+1) + '.' + str(j+1) + '=' + str(tranProbMat[i][j]) + ',\n')
    f.write('\n')
    
    # Write variables
    f.write('Variables\n')
    f.write('\tf\n')
    f.write('\ta(t,k)\n')
    f.write('\tinTerm(t,k);\n\n')
    f.write('Integer variables a;\n\n')
    
    # Write equations
    f.write('Equations obj, eq1(t,i), eq1_base(t,i), eq2(t) ;\n')
    f.write('obj(tt).. f =e= Sum(i, exp(inTerm(tt,i)));\n')
    f.write('eq1(tn(t),i).. exp(inTerm(t,i)) =e= Sum(j, P(i,j) * (miss(j) ** a(t,j)) * exp(inTerm(t-1,j)));\n')
    f.write('eq1_base(tb,i).. exp(inTerm(tb,i)) =e= Sum(j, P(i,j) * (miss(j) ** a(tb,j)) * prior(j));\n')
    #f.write('obj(tt).. f =e= Sum(i, inTerm(tt,i));\n')
    #f.write('eq1(tn(t),i).. inTerm(t,i) =e= Sum(j, P(i,j) * (miss(j) ** a(t,j)) * inTerm(t-1,j));\n')
    #f.write('eq1_base(tb,i).. inTerm(tb,i) =e= Sum(j, P(i,j) * (miss(j) ** a(tb,j)) * prior(j));\n')
    f.write('eq2(t).. Sum(k, a(t,k)) =e= M ;\n\n')
    
    # Write model
    f.write('Model search_problem /all/ ;\n\n')
    
    # Write time limit
    f.write('search_problem.reslim = 3600;\n\n')
    
    # Write enable option file
    f.write('search_problem.optfile = 1 ;\n\n')
    
    # Write solve
    f.write('Solve search_problem using minlp minimizing f ;\n')
    
    # Close file
    f.close()

# %%
if runGAMS:
    writeGamsModel(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec)

# %% [markdown]
# ## Compute lower bound

# %%
def solveRelaxedSubproblem(agentN, locN, stageN, missVec, q):
    action = [ 0.0 ] * locN
    lamb = 0
    for k in range(locN):
        lamb = max(lamb, - q[k] * math.log(missVec[k]))
    left = 0.0
    right = lamb
    itr = 1
    while True:
        # Solve for action with current lamb
        for k in range(locN):
            if (q[k] * math.log(missVec[k]) + lamb >= 0):
                action[k] = 0;
            else:
                tmp = - lamb / (q[k] * math.log(missVec[k]))
                action[k] = math.log(tmp, missVec[k])
        if math.fabs(sum(action) - agentN) <= 1e-13:
            break
        elif sum(action) > agentN: # Increase lamb thus decrease action
            tmp = lamb
            lamb = (lamb + right) / 2.0
            left = tmp
        else: # Decrease lamb thus increase action
            tmp = lamb
            lamb = (left + lamb) / 2.0
            right = tmp
        itr += 1
    return action

# %%
def getLowerBound(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec):    
    # Initialize the decision variables (indexes of locations chosen at each stage)
    # Alert: if use [[0]*locN]*stageN, then we have stageN lists referencing to the same list
    actionVec = [ [0] * locN for s in range(stageN) ] 
    
    # Initialize qR
    qR = np.empty([stageN,locN])
    qR[0,:] = priorVec

    # Initialize qL
    qL = np.ones((stageN,locN))
    
    # Solve the relaxed problem
    prevObjVal = 1.0
    cycleN = 0
    while True:
        cycleN += 1
        # Forward recursion
        for s in range(stageN-1): # s=0,...,T-2
            # Solve subproblem
            q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
            actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
            # update qR
            tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, actionVec[s])
            qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
        # Backward recursion
        for s in reversed(range(1,stageN)): # s=T-1,...,1
            # Solve subproblem
            q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
            actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
            # update qL
            tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, actionVec[s])
            qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix

        # Compute new objective value
        curObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
        # Decide if reaches the optimum
        if curObjVal >= prevObjVal:
            break
        prevObjVal = curObjVal
    return prevObjVal

# %%
if runGetLowerBound:
    optLowerBound = getLowerBound(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec)

# %% [markdown]
# ## Forward-Backward Iterative Algorithm

# %%
def forBackIter(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, relaxedRecur=True): 
    # Initialize the decision variables (indexes of locations chosen at each stage)
    # Alert: if use [[0]*locN]*stageN, then we have stageN lists referencing to the same list
    actionVec = [ [0] * locN for s in range(stageN) ] 
    
    # Initialize qR
    qR = np.empty([stageN,locN])
    qR[0,:] = priorVec

    # Initialize qL
    qL = np.ones((stageN,locN))
    
    # Relaxed Forward-Backward Recursions
    if relaxedRecur == True:
        prevObjVal = 1.0
        cycleN = 0
        while True:
            cycleN += 1
            # Forward recursion
            print('\n==== Relaxed forward recursion starts ====\n')
            for s in range(stageN-1): # s=0,...,T-2
                print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
                actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
                # Update qR
                tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
            # Backward recursion
            print('\n==== Relaxed backward recursion starts ====\n')
            for s in reversed(range(1,stageN)): # s=T-1,...,1
                print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
                actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
                # Update qL
                tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix

            # Compute new objective value
            curObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
            print('\nThe objective value becomes: %.4f' % (curObjVal) + '\n')
            # Decide if the relaxed recursions terminates
            if curObjVal >= prevObjVal:
                break
            prevObjVal = curObjVal
      
    # Integer Forward-Backward Recursions
    prevObjVal = 1.0
    cycleN = 0
    isPrintAction = False
    while True:
        cycleN += 1
        # Forward recursion
        print('\n==== Integer forward recursion starts ====\n')
        for s in range(stageN-1): # s=0,...,T-2
            print('\n---Stage ' + str(s) + '---\n')
            # Solve subproblem
            action = [0] * locN
            heap = []
            for k in range(locN):
                heapq.heappush(heap, (- qL[s,k] * qR[s,k] * detectVec[k], k))
            for m in range(agentN):
                ele = heapq.heappop(heap)
                action[ele[1]] += 1
                heapq.heappush(heap, (ele[0] * missVec[ele[1]], ele[1]))
            actionVec[s] = action
            if isPrintAction:
                print('\nThe actions become:\n')
                print(actionVec)
            # Update qR
            tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, actionVec[s])
            qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
        # Backward recursion
        print('\n==== Integer backward recursion starts ====\n')
        for s in reversed(range(1,stageN)): # s=T-1,...,1
            print('\n---Stage ' + str(s) + '---\n')
            # Solve subproblem
            action = [0] * locN
            heap = []
            for k in range(locN):
                heapq.heappush(heap, (- qL[s,k] * qR[s,k] * detectVec[k], k))
            for m in range(agentN):
                ele = heapq.heappop(heap)
                action[ele[1]] += 1
                heapq.heappush(heap, (ele[0] * missVec[ele[1]], ele[1]))
            actionVec[s] = action
            if isPrintAction:
                print('\nThe actions become:\n')
                print(actionVec)
            # Update qL
            tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, actionVec[s])
            qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix
        
        # Compute new objective value
        curObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
        print('\nThe objective value becomes: %.4f' % (curObjVal) + '\n')
        # Decide if the algorithm terminates (must run more than one cycle)
        if curObjVal >= prevObjVal and cycleN > 1:
            return [curObjVal, actionVec, cycleN]
        prevObjVal = curObjVal
    return [curObjVal, actionVec, cycleN]

# %%
if runOur_oneStage:
    start_time_our_oneStage = time.time()
    [optObjVal_our_oneStage, optActionVec_our_oneStage, cycleN_our_oneStage] = \
        forBackIter(agentN, locN, stageN, priorVec, tranProbMat, \
                    detectVec, missVec, relaxedRecur=False)
    time_elapsed_our_oneStage = time.time() - start_time_our_oneStage

# %%
if runOur_twoStage:
    start_time_our_twoStage = time.time()
    [optObjVal_our_twoStage, optActionVec_our_twoStage, cycleN_our_twoStage] = \
        forBackIter(agentN, locN, stageN, priorVec, tranProbMat, \
                    detectVec, missVec, relaxedRecur=True)
    time_elapsed_our_twoStage = time.time() - start_time_our_twoStage

# %% [markdown]
# ## Forward-Backward Iterative Algorithm (Random)

# %%
def forBackIterRandom(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, relaxedRecur=True, randomRepetitions=10): 
    # Initialize the decision variables (indexes of locations chosen at each stage)
    # Alert: if use [[0]*locN]*stageN, then we have stageN lists referencing to the same list
    actionVec = [ [0] * locN for s in range(stageN) ] 

    # Initialize qR
    qR = np.empty([stageN,locN])
    qR[0,:] = priorVec

    # Initialize qL
    qL = np.ones((stageN,locN))
    
    # Relaxed Forward-Backward Recursions
    if relaxedRecur == True:
        prevObjVal = 1.0
        cycleN = 0
        isPrintQ = False
        while True:
            cycleN += 1
            # Forward recursion
            print('\n==== Relaxed forward recursion starts ====\n')
            for s in range(stageN-1): # s=0,...,T-2
                #print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
                actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
                # Update qR
                tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
            # Backward recursion
            print('\n==== Relaxed backward recursion starts ====\n')
            for s in reversed(range(1,stageN)): # s=T-1,...,1
                #print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                q = [ a*b for a,b in zip(qL[s,:],qL[s,:]) ]
                actionVec[s] = solveRelaxedSubproblem(agentN, locN, stageN, missVec, q)
                # Update qL
                tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix

            # Compute new objective value
            curObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
            print('\nThe objective value becomes: %.4f' % (curObjVal) + '\n')
            # Decide if the relaxed recursions terminates
            if curObjVal >= prevObjVal:
                break
            prevObjVal = curObjVal
        actionDistVec = np.array(actionVec)
        row_sums = actionDistVec.sum(axis=1)
        actionDistVec = actionDistVec / row_sums[:, np.newaxis]
    else:
        actionDistVec = [ [1.0 / locN] * locN ] * stageN
    
    optObjVal = 1.0
    for rep in range(randomRepetitions):
        # Randomly generate intial actionVec
        actionVec = [ [0] * locN ] * stageN
        for s in range(stageN):
            actionVec[s] = np.random.multinomial(agentN, actionDistVec[s])
        
        # Compute qL (no need to compute qR here)
        for s in reversed(range(1, stageN)):
            tmp_q = np.copy(qL[s,:])
            tmp_Is = np.power(missVec, actionVec[s])
            qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q))
        
        # Integer Forward-Backward Recursions
        prevObjVal = 1.0
        cycleN = 0
        isPrintAction = False
        while True:
            cycleN += 1
            # Forward recursion
            print('\n==== Rep ' + str(rep) + ': Integer forward recursion starts ====\n')
            for s in range(stageN-1): # s=0,...,T-2
                #print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                action = [0] * locN
                heap = []
                for k in range(locN):
                    heapq.heappush(heap, (- qL[s,k] * qR[s,k] * detectVec[k], k))
                for m in range(agentN):
                    ele = heapq.heappop(heap)
                    action[ele[1]] += 1
                    heapq.heappush(heap, (ele[0] * missVec[ele[1]], ele[1]))
                actionVec[s] = action
                if isPrintAction:
                    print('\nThe actions become:\n')
                    print(actionVec)
                # Update qR
                tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
            # Backward recursion
            print('\n==== Rep ' + str(rep) + ': Integer backward recursion starts ====\n')
            for s in reversed(range(1,stageN)): # s=T-1,...,1
                #print('\n---Stage ' + str(s) + '---\n')
                # Solve subproblem
                action = [0] * locN
                heap = []
                for k in range(locN):
                    heapq.heappush(heap, (- qL[s,k] * qR[s,k] * detectVec[k], k))
                for m in range(agentN):
                    ele = heapq.heappop(heap)
                    action[ele[1]] += 1
                    heapq.heappush(heap, (ele[0] * missVec[ele[1]], ele[1]))
                actionVec[s] = action
                if isPrintAction:
                    print('\nThe actions become:\n')
                    print(actionVec)
                # Update qL
                tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
                tmp_Is = np.power(missVec, actionVec[s])
                qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix

            # Compute new objective value
            curObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
            print('\nThe objective value becomes: %.4f' % (curObjVal) + '\n')
            # Decide if the algorithm terminates (must run more than one cycle)
            if curObjVal >= prevObjVal and cycleN > 1:
                break
            prevObjVal = curObjVal
        if curObjVal < optObjVal:
            optObjVal = curObjVal
            optActionVec = actionVec
    return [optObjVal, optActionVec, randomRepetitions]

# %%
if runOur_oneStage_random:
    start_time_our_oneStage_random = time.time()
    [optObjVal_our_oneStage_random, optActionVec_our_oneStage_random, randomRepetitionN_our_oneStage_random] = \
        forBackIterRandom(agentN, locN, stageN, priorVec, tranProbMat, \
                          detectVec, missVec, relaxedRecur=False, randomRepetitions=20)
    time_elapsed_our_oneStage_random = time.time() - start_time_our_oneStage_random

# %%
if runOur_twoStage_random:
    start_time_our_twoStage_random = time.time()
    [optObjVal_our_twoStage_random, optActionVec_our_twoStage_random, randomRepetitionN_our_twoStage_random] = \
        forBackIterRandom(agentN, locN, stageN, priorVec, tranProbMat, \
                          detectVec, missVec, relaxedRecur=True, randomRepetitions=20)
    time_elapsed_our_twoStage_random = time.time() - start_time_our_twoStage_random

# %% [markdown]
# ## Cutting-Plane Algorithm 2
#
# ### In paper "Route Optimization for Multiple Searchers" by Royset and Sato

# %%
def roysetSatoAlg2(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, delta=1e-10):
    # Build Gurobi model
    model = gurobi.Model("Royset-Sato Alg 2")
    # Add variables
    a = {}
    for s in range(stageN):
        for k in range(locN):
            a[s,k] = model.addVar(obj=0, vtype='I', lb=0, ub=agentN, name='a'+str(s)+','+str(k))
    xi = model.addVar(obj=1.0, name='xi')
    # Add constraints
    for s in range(stageN):
        coef = [ 1 for k in range(locN) ]
        var = [ a[s,k] for k in range(locN) ]
        model.addConstr(gurobi.LinExpr(coef,var), '=', agentN)
    # Do not print Gurobi messages
    model.setParam('OutputFlag', False)
    # Update model
    model.update()

    # Cutting-plane
    total_time = 0.0  # total time used
    start_time = time.time()  # start time
    hi = 1.0  # upper bound of optimal value
    lo = 0.0  # lower bound of optimal value
    prev_a = [ [0] * locN for s in range(stageN) ]  # initialize T-period actions
    delta_i = 0.0  # expected MIP optimality gap for problem P_i
    delta_i_half_flag = False  # if lower bound has not changed after one iteration, halve delta_i
    itr = 1  # iteration counter
    while True:
        # Compute current value and update upper bound of optimal value
        f_a = computeObjVal(stageN, priorVec, tranProbMat, missVec, prev_a)
        if f_a < hi:
            hi = f_a
        
        # Decide if terminates
        if hi - lo <= delta * lo:
            optActionVec = prev_a
            break
        
        # Compute qR for prev_a
        qR = np.empty([stageN,locN])
        qR[0,:] = priorVec
        for s in range(stageN-1): # s=0,...,T-2
            tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, prev_a[s])
            qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
        
        # Compute qL for prev_a
        qL = np.ones((stageN,locN))
        for s in reversed(range(1,stageN)): # s=T-1,...,1
            tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, prev_a[s])
            qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix
        
        # Add one more constraint
        constr_lhs = f_a
        for s in range(stageN):
            for k in range(locN):
                constr_lhs += qL[s][k] * qR[s][k] * (missVec[k] ** prev_a[s][k]) \
                              * (-detectVec[k]) * (a[s,k] - prev_a[s][k])
        model.addConstr(constr_lhs, '<=', xi)
        
        '''
        # Set MIP optimality gap = (Upper - Lower) / Upper
        if itr == 2:
            delta_i = min(0.03, (hi - lo) / lo)
        elif itr > 2:
            if delta_i < 1e-10:
                delta_i = 0.0
            else:
                if delta_i_half_flag:
                    delta_i /= 2.0
                delta_i = min(delta_i, 0.03)
                delta_i = min(delta_i, (hi - lo) / lo)
        model.setParam("MIPGap", delta_i / (1 + delta_i));
        '''
        
        # Update model and solve
        model.update()
        model.optimize()
        
        # Retrieve Gurobi outputs
        prev_a = [ [0] * locN for s in range(stageN) ]
        for s in range(stageN):
            for k in range(locN):
                prev_a[s][k] = model.getVarByName('a'+str(s)+','+str(k)).X
        MIP_solution = model.getVarByName('xi').X
        if MIP_solution > lo:
            lo = MIP_solution
            delta_i_half_flag = False
        else:
            delta_i_half_flag = True  # if lower bound does not change, halve delta_i in next iteration
        
        # Update total time
        total_time = time.time() - start_time
        
        # Compute relative optimality gap:
        if lo != 0.0:
            g_i = (hi - lo) / lo
        else:
            g_i = math.inf
        
        # Print debugging info
        print("iter=%s, rela_gap=%.5f, hi=%.10f, lo=%.10f, fun_value=%.10f, MIP_solution=%.10f, \
               delta_i=%.3e, time_taken=%.1f" \
               % (itr, g_i, hi, lo, f_a, MIP_solution, \
                  delta_i, total_time))
        
        # Decide if terminates
        if hi - lo <= delta * lo:
            optActionVec = prev_a
            break
        
        itr += 1
    optObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, optActionVec)
    return [optObjVal, optActionVec]

# %%
if runRoyset2:
    start_time_royset2 = time.time()
    [optObjVal_royset2, optActionVec_royset2] = \
        roysetSatoAlg2(agentN, locN, stageN, priorVec, tranProbMat, \
                       detectVec, missVec, delta=1e-10)
    time_elapsed_royset2 = time.time() - start_time_royset2
# Out:
# iter=1, rela_gap=inf, hi=1.0000000000, lo=0.0000000000, fun_value=1.0000000000, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.1
# iter=2, rela_gap=inf, hi=0.8354690882, lo=0.0000000000, fun_value=0.8354690882, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.2
# iter=3, rela_gap=inf, hi=0.8332939528, lo=0.0000000000, fun_value=0.8332939528, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.4
# iter=4, rela_gap=inf, hi=0.8167298621, lo=0.0000000000, fun_value=0.8167298621, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.5
# iter=5, rela_gap=inf, hi=0.8167298621, lo=0.0000000000, fun_value=0.8257891151, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.7
# iter=6, rela_gap=inf, hi=0.8167298621, lo=0.0000000000, fun_value=0.8258268314, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=0.8
# iter=7, rela_gap=inf, hi=0.8167298621, lo=0.0000000000, fun_value=0.8267460828, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.0
# iter=8, rela_gap=inf, hi=0.8072188004, lo=0.0000000000, fun_value=0.8072188004, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.2
# iter=9, rela_gap=inf, hi=0.8072188004, lo=0.0000000000, fun_value=0.8101774930, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.3
# iter=10, rela_gap=inf, hi=0.8072188004, lo=0.0000000000, fun_value=0.8102555239, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.4
# iter=11, rela_gap=inf, hi=0.8072188004, lo=0.0000000000, fun_value=0.8163267535, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.5
# iter=12, rela_gap=inf, hi=0.8072188004, lo=0.0000000000, fun_value=0.8097780647, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.7
# iter=13, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7743486239, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=1.9
# iter=14, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8175327692, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.0
# iter=15, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8021340464, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.2
# iter=16, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8077519987, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.3
# iter=17, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8380702912, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.5
# iter=18, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8279081015, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.6
# iter=19, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8011039893, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.8
# iter=20, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8375331974, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=2.9
# iter=21, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8130848481, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.0
# iter=22, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8281510527, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.2
# iter=23, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7939523565, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.4
# iter=24, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8208981007, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.5
# iter=25, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8398979037, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.7
# iter=26, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8297391991, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=3.8
# iter=27, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8393104764, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.0
# iter=28, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8292501700, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.2
# iter=29, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7920505816, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.4
# iter=30, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8217706467, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.6
# iter=31, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8393067530, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.8
# iter=32, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8030311166, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=4.9
# iter=33, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7785775275, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.1
# iter=34, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8380062594, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.3
# iter=35, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7954586067, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.4
# iter=36, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7757053659, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.6
# iter=37, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7792679376, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.7
# iter=38, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8296858325, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=5.9
# iter=39, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7945528242, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=6.0
# iter=40, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8413452630, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=6.1
# iter=41, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8133020299, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=6.4
# iter=42, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7848040825, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=6.6
# iter=43, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8410082406, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=6.8
# iter=44, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8192696025, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.0
# iter=45, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8325338397, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.2
# iter=46, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7956139311, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.4
# iter=47, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8322243506, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.6
# iter=48, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8030415261, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.8
# iter=49, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8050833317, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=7.9
# iter=50, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8304917363, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=8.1
# iter=51, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8065729213, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=8.3
# iter=52, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8348729868, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=8.5
# iter=53, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8248281956, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=8.6
# iter=54, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8223645288, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=8.8
# iter=55, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8231130360, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.0
# iter=56, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8074924779, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.2
# iter=57, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8205413152, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.3
# iter=58, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8333152291, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.5
# iter=59, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8337255628, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.7
# iter=60, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8426601648, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=9.9
# iter=61, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8442031762, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=10.0
# iter=62, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8335358153, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=10.2
# iter=63, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8406821396, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=10.6
# iter=64, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8135206196, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=10.8
# iter=65, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8404948788, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=11.0
# iter=66, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8405037252, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=11.2
# iter=67, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8206003162, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=11.4
# iter=68, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8199249825, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=11.5
# iter=69, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8073175250, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=11.7
# iter=70, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8432045522, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=12.1
# iter=71, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8267218355, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=12.3
# iter=72, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8254022807, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=12.5
# iter=73, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8132392592, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=12.7
# iter=74, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8078323190, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=12.9
# iter=75, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7810052785, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=13.1
# iter=76, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8229292752, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=13.4
# iter=77, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8088999950, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=13.6
# iter=78, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8428244974, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=13.9
# iter=79, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8392308860, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=14.1
# iter=80, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.7918724089, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=14.3
# iter=81, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8139454799, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=14.6
# iter=82, rela_gap=inf, hi=0.7743486239, lo=0.0000000000, fun_value=0.8455172454, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=14.8
# iter=83, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.7447686964, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=15.1
# iter=84, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8411291475, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=15.3
# iter=85, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8132524943, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=15.6
# iter=86, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8059310182, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=15.8
# iter=87, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8432644900, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=16.0
# iter=88, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8445476687, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=16.3
# iter=89, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8100735695, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=16.5
# iter=90, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8022312577, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=16.8
# iter=91, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8232058884, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=17.0
# iter=92, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8363834780, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=17.3
# iter=93, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8238404467, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=17.5
# iter=94, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8233752809, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=17.8
# iter=95, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8328513230, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=18.0
# iter=96, rela_gap=inf, hi=0.7447686964, lo=0.0000000000, fun_value=0.8405825847, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=18.2
# iter=97, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7305648928, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=18.5
# iter=98, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8307833300, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=18.8
# iter=99, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8342379206, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=19.0
# iter=100, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7913520648, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=19.3
# iter=101, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8149476824, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=19.6
# iter=102, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8194969952, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=19.9
# iter=103, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8304479885, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=20.1
# iter=104, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8311789944, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=20.4
# iter=105, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8038713733, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=20.7
# iter=106, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8304326980, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=20.9
# iter=107, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7789745234, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=21.3
# iter=108, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8286047702, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=21.6
# iter=109, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8178557921, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=21.9
# iter=110, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8249452314, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=22.3
# iter=111, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8307341061, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=22.6
# iter=112, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8221849327, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=22.9
# iter=113, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8155461063, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=23.1
# iter=114, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7320331195, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=23.4
# iter=115, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8394408380, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=23.7
# iter=116, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8212156932, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=24.0
# iter=117, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7807070173, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=24.2
# iter=118, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8060273248, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=24.5
# iter=119, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8034608049, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=24.8
# iter=120, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8252945435, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=25.1
# iter=121, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8280373216, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=25.5
# iter=122, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8158285053, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=25.8
# iter=123, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8428247988, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=26.2
# iter=124, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8421951336, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=26.6
# iter=125, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8452443691, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=26.9
# iter=126, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7943518639, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=27.4
# iter=127, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8160135331, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=27.8
# iter=128, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8251300070, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=28.2
# iter=129, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8234456163, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=28.5
# iter=130, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8411199424, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=29.0
# iter=131, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8082023866, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=29.4
# iter=132, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7868111719, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=29.7
# iter=133, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8392196983, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=30.0
# iter=134, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8267173073, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=30.5
# iter=135, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8039368118, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=30.9
# iter=136, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7903444856, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=31.3
# iter=137, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8249042805, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=31.7
# iter=138, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8422853245, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=32.1
# iter=139, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7616979279, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=32.5
# iter=140, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7760367037, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=32.9
# iter=141, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8073767157, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=33.3
# iter=142, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8328089664, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=33.7
# iter=143, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8213151752, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=34.0
# iter=144, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8390972390, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=34.4
# iter=145, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8259874649, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=34.8
# iter=146, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8338497751, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=35.2
# iter=147, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7772960386, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=35.6
# iter=148, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8270173821, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=35.9
# iter=149, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8418943462, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=36.4
# iter=150, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7881841792, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=36.8
# iter=151, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8248929204, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=37.2
# iter=152, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8211096948, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=37.6
# iter=153, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7976708719, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=38.1
# iter=154, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8136754546, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=38.5
# iter=155, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8431307008, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=39.0
# iter=156, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8230524861, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=39.3
# iter=157, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8150401417, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=39.7
# iter=158, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8410315135, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=40.2
# iter=159, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8252095912, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=40.6
# iter=160, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8431791023, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=41.0
# iter=161, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8165339256, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=41.4
# iter=162, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8407232210, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=41.8
# iter=163, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7998610681, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=42.2
# iter=164, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8406109426, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=42.6
# iter=165, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8315278958, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=43.0
# iter=166, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8012161622, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=43.5
# iter=167, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8422428895, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=43.9
# iter=168, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8136793868, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=44.3
# iter=169, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8329829524, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=44.9
# iter=170, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8060198601, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=45.4
# iter=171, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8218202988, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=45.9
# iter=172, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8075686357, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=46.5
# iter=173, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8408700970, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=46.9
# iter=174, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8413790039, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=47.4
# iter=175, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8423185138, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=47.9
# iter=176, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8061978435, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=48.5
# iter=177, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8304122746, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=49.0
# iter=178, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7877467702, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=49.5
# iter=179, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8436600662, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=49.9
# iter=180, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8434552425, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=50.4
# iter=181, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8065481531, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=50.8
# iter=182, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8422175224, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=51.3
# iter=183, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7466347950, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=51.8
# iter=184, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8026409854, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=52.4
# iter=185, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8341517801, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=52.9
# iter=186, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7836062067, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=53.3
# iter=187, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8319931861, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=53.9
# iter=188, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8436697377, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=54.4
# iter=189, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8416222443, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=55.0
# iter=190, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7894200383, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=55.5
# iter=191, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8445253613, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=56.0
# iter=192, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7875277040, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=56.5
# iter=193, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8419889209, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=57.0
# iter=194, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7880831728, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=57.5
# iter=195, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8145764196, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=58.0
# iter=196, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7994869932, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=58.6
# iter=197, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8406801321, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=59.2
# iter=198, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8415549302, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=59.7
# iter=199, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7792963976, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=60.2
# iter=200, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8428686991, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=60.6
# iter=201, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8209630954, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=61.1
# iter=202, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8261925218, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=61.6
# iter=203, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8028637294, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=62.2
# iter=204, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8141689997, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=62.7
# iter=205, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8082718792, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=63.2
# iter=206, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8413820898, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=63.7
# iter=207, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8437179748, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=64.3
# iter=208, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8338853555, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=64.8
# iter=209, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8309505944, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=65.3
# iter=210, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8417693193, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=65.8
# iter=211, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8088744101, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=66.3
# iter=212, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8425954222, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=66.9
# iter=213, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7998184473, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=67.4
# iter=214, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8227796842, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=68.0
# iter=215, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8395687411, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=68.5
# iter=216, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8458547701, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=69.0
# iter=217, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7501602733, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=69.6
# iter=218, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7744843719, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=70.2
# iter=219, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8012094202, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=70.7
# iter=220, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7768506584, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=71.2
# iter=221, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8074038155, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=71.8
# iter=222, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8444680181, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=72.3
# iter=223, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7967274458, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=72.9
# iter=224, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8196465553, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=73.4
# iter=225, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8249112581, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=74.0
# iter=226, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7903074640, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=74.5
# iter=227, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8310361508, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=75.1
# iter=228, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8165182903, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=75.7
# iter=229, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8434354635, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=76.2
# iter=230, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8435439607, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=76.8
# iter=231, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8407575586, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=77.4
# iter=232, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8432273351, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=78.0
# iter=233, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7890276022, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=78.6
# iter=234, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8409414769, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=79.1
# iter=235, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8246412988, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=79.7
# iter=236, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8167540813, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=80.3
# iter=237, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8249334555, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=80.8
# iter=238, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8077042552, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=81.4
# iter=239, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8173104229, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=82.0
# iter=240, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8154314724, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=82.5
# iter=241, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7830405056, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=83.1
# iter=242, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8438134454, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=83.7
# iter=243, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8255025275, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=84.4
# iter=244, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8225711912, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=85.1
# iter=245, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8046156748, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=85.7
# iter=246, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8442626176, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=86.4
# iter=247, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8389967967, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=87.1
# iter=248, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8325119928, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=87.8
# iter=249, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8227652919, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=88.5
# iter=250, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8461947819, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=89.2
# iter=251, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8438825802, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=89.9
# iter=252, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8246530086, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=90.6
# iter=253, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8146146570, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=91.2
# iter=254, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8352005880, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=91.9
# iter=255, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8269814453, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=92.6
# iter=256, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8060278904, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=93.2
# iter=257, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8028400758, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=93.9
# iter=258, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8267637978, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=94.6
# iter=259, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8309682421, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=95.2
# iter=260, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8434575583, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=95.9
# iter=261, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8505908743, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=96.6
# iter=262, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7723122295, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=97.4
# iter=263, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8256647331, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=98.1
# iter=264, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8027340075, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=98.8
# iter=265, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8073555092, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=99.6
# iter=266, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7511017268, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=100.3
# iter=267, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8236023251, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=101.0
# iter=268, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8416315033, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=101.7
# iter=269, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8227617084, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=102.4
# iter=270, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8438326790, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=103.1
# iter=271, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8343295908, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=103.8
# iter=272, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8369887842, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=104.6
# iter=273, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8437785628, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=105.3
# iter=274, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8428279584, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=106.0
# iter=275, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8234117010, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=106.7
# iter=276, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7932080704, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=107.4
# iter=277, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8064649119, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=108.1
# iter=278, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8241559325, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=108.8
# iter=279, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8131428941, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=109.5
# iter=280, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8176056939, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=110.2
# iter=281, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8131344060, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=110.9
# iter=282, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8060462715, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=111.6
# iter=283, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7847425944, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=112.3
# iter=284, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7880932499, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=113.0
# iter=285, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8174162251, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=113.7
# iter=286, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7769029147, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=114.4
# iter=287, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8236993852, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=115.2
# iter=288, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8151351471, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=115.9
# iter=289, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8431072566, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=116.7
# iter=290, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7999640874, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=117.5
# iter=291, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8329319636, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=118.3
# iter=292, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8318460230, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=119.0
# iter=293, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8439042229, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=119.8
# iter=294, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8040900656, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=120.6
# iter=295, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8466906025, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=121.5
# iter=296, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8424745490, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=122.3
# iter=297, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8373368922, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=123.1
# iter=298, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8030943384, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=123.9
# iter=299, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8433480551, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=124.7
# iter=300, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8411118481, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=125.6
# iter=301, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.7739516998, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=126.4
# iter=302, rela_gap=inf, hi=0.7305648928, lo=0.0000000000, fun_value=0.8441208899, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=127.2
# ...
# iter=344, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8464764444, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=163.5
# iter=345, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8068471329, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=164.5
# iter=346, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8388345458, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=165.6
# iter=347, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8266709055, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=166.6
# iter=348, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8294052548, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=167.5
# iter=349, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8447409983, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=168.5
# iter=350, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8084694837, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=169.4
# iter=351, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7844643858, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=170.5
# iter=352, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8149361157, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=171.5
# iter=353, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8253136711, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=172.6
# iter=354, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8044950875, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=173.7
# iter=355, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8347792789, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=174.6
# iter=356, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8441206645, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=175.6
# iter=357, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8266499138, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=176.6
# iter=358, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7862833361, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=177.7
# iter=359, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7880025275, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=178.8
# iter=360, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8031057679, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=179.9
# iter=361, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8436873413, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=181.0
# iter=362, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8250084428, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=182.0
# iter=363, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8241654557, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=183.1
# iter=364, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8362891058, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=184.1
# iter=365, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8249384485, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=185.3
# iter=366, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7833310506, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=186.4
# iter=367, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8345650304, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=187.4
# iter=368, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7887324422, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=188.5
# iter=369, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7838512879, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=189.5
# iter=370, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8431367724, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=190.6
# iter=371, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7859304429, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=191.5
# iter=372, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8325765303, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=192.7
# iter=373, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8268552775, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=193.8
# iter=374, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8189606062, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=194.8
# iter=375, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8430298186, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=196.0
# iter=376, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8350460821, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=197.1
# iter=377, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8339093234, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=198.3
# iter=378, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8262770864, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=199.3
# iter=379, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8264104270, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=200.5
# iter=380, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8082213295, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=201.6
# iter=381, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7887993013, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=202.8
# iter=382, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7859562303, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=203.9
# iter=383, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8274997905, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=205.0
# iter=384, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7842288432, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=206.1
# iter=385, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8166833643, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=207.2
# iter=386, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8091934624, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=208.3
# iter=387, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8032871651, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=209.3
# iter=388, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8315221975, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=210.6
# iter=389, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7867469265, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=211.6
# iter=390, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7869783216, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=212.9
# iter=391, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8261246111, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=214.0
# iter=392, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8403911637, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=215.2
# iter=393, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8022647481, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=216.3
# iter=394, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8424938283, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=217.5
# iter=395, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8448588009, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=218.6
# iter=396, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8209115422, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=219.7
# iter=397, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8420011483, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=220.8
# iter=398, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8246059860, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=222.2
# iter=399, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8215560349, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=223.4
# iter=400, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8471811647, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=224.8
# iter=401, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8125958358, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=226.0
# iter=402, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8460357768, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=227.3
# iter=403, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8033393220, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=228.5
# iter=404, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8001789884, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=229.7
# iter=405, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7984028335, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=231.0
# iter=406, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8162657916, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=232.1
# iter=407, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8143176248, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=233.3
# iter=408, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8422771019, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=234.4
# iter=409, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8227605689, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=235.6
# iter=410, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7991783054, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=236.8
# iter=411, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8244208766, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=238.1
# iter=412, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8019742710, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=239.5
# iter=413, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7991838091, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=240.8
# iter=414, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8326708304, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=242.3
# iter=415, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8125503892, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=243.5
# iter=416, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.8002190462, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=244.9
# iter=417, rela_gap=inf, hi=0.7266988537, lo=0.0000000000, fun_value=0.7969701021, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=246.3
# iter=418, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8275610722, MIP_solution=0.0142028332,                delta_i=0.000e+00, time_taken=246.9
# iter=419, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8596194066, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=248.0
# iter=420, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8256691664, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=249.2
# iter=421, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8085285320, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=250.4
# iter=422, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.7986390575, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=251.5
# iter=423, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8081244227, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=252.4
# iter=424, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8337726743, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=253.4
# iter=425, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8503826361, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=254.4
# iter=426, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8174032960, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=255.4
# iter=427, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8181742705, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=256.4
# iter=428, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8276197941, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=257.3
# iter=429, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8417529734, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=258.3
# iter=430, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8430523952, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=259.3
# iter=431, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8419126743, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=260.4
# iter=432, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8192484163, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=261.6
# iter=433, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8415673410, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=262.7
# iter=434, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8070621501, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=263.9
# iter=435, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8479125795, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=265.0
# iter=436, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8317679526, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=266.1
# iter=437, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8199316321, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=267.0
# iter=438, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8253032262, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=268.1
# iter=439, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8053289277, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=269.1
# iter=440, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.8312245987, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=270.2
# iter=441, rela_gap=50.16577, hi=0.7266988537, lo=0.0142028332, fun_value=0.7828294088, MIP_solution=0.0000000000,                delta_i=0.000e+00, time_taken=271.1
# iter=442, rela_gap=-0.15463, hi=0.7266988537, lo=0.8596193790, fun_value=0.7976141487, MIP_solution=0.8596193790,                delta_i=0.000e+00, time_taken=271.6

# %% [markdown]
# ## Cutting-Plane Algorithm 3
#
# ### In paper "Route Optimization for Multiple Searchers" by Royset and Sato

# %%
def roysetSatoAlg3(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, delta=1e-10):
    # Build Gurobi model
    model = gurobi.Model("Royset-Sato Alg 3")
    # Add variables
    a = {}
    for s in range(stageN):
        for k in range(locN):
            a[s,k] = model.addVar(obj=0, vtype='C', lb=0, ub=agentN, name='a'+str(s)+','+str(k))  # set a as continuous and 0<=a(s,k)<=M
    xi = model.addVar(obj=1.0, name='xi')
    # Add constraints
    for s in range(stageN):
        coef = [ 1 for k in range(locN) ]
        var = [ a[s,k] for k in range(locN) ]
        model.addConstr(gurobi.LinExpr(coef,var), '=', agentN)
    # Do not print Gurobi messages
    model.setParam('OutputFlag', False)
    # Update model
    model.update()

    # Cutting-plane
    total_time = 0.0  # total time used
    start_time = time.time()  # start time
    hi = 1.0  # upper bound of optimal value
    lo = 0.0  # lower bound of optimal value
    prev_a = [ [0] * locN for s in range(stageN) ]  # initialize T-period actions
    delta_i = 0.0  # expected MIP optimality gap for problem P_i
    delta_i_half_flag = False  # if lower bound has not changed after one iteration, halve delta_i
    hasSwap_relax_to_int_flag = False  # if has just swapped from continuous relaxtion to integer problem
                                       # if not done yet, need to do a.setAttr('vtype', 'I')
    itr = 1  # iteration counter
    while True:
        # Compute current value and update upper bound of optimal value
        f_a = computeObjVal(stageN, priorVec, tranProbMat, missVec, prev_a)
        if f_a < hi:
            hi = f_a
            optActionVec = prev_a
        
        # Decide if terminates
        if hi - lo <= delta * lo:
            break
        
        # Compute relative optimality gap:
        if lo != 0.0:
            g_i = (hi - lo) / lo
        else:
            g_i = math.inf
        
        # Compute qR for prev_a
        qR = np.empty([stageN,locN])
        qR[0,:] = priorVec
        for s in range(stageN-1): # s=0,...,T-2
            tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, prev_a[s])
            qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))

        # Compute qL for prev_a
        qL = np.ones((stageN,locN))
        for s in reversed(range(1,stageN)): # s=T-1,...,1
            tmp_q = np.copy(qL[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, prev_a[s])
            qL[s-1,:] = tranProbMat.T.dot(np.multiply(tmp_Is, tmp_q)) # remember to transpose the transition matrix

        # Add one more constraint
        constr_lhs = f_a
        if g_i > 1e-3 and total_time < 600:  # solve continuous relaxation first
            for s in range(stageN):
                for k in range(locN):
                    constr_lhs += qL[s][k] * qR[s][k] * (missVec[k] ** prev_a[s][k]) \
                                  * math.log(missVec[k]) * (a[s,k] - prev_a[s][k])
        else:
            # If this is the first time swapping from relaxed to integer, reset variable attribute
            if not hasSwap_relax_to_int_flag:
                for s in range(stageN):
                    for k in range(locN):
                        a[s,k].setAttr('vtype', 'I')
                print("iter=%s, rela_gap=%.6f, hi=%s, lo=%s, delta_i=%s, time_taken=%.2f" \
                      % (itr, g_i, hi, lo, delta_i, total_time))
                print("========== Swapping from relaxed to integer ==========")
                hasSwap_relax_to_int_flag = True
            for s in range(stageN):
                for k in range(locN):
                    constr_lhs += qL[s][k] * qR[s][k] * (missVec[k] ** prev_a[s][k]) \
                                  * (-detectVec[k]) * (a[s,k] - prev_a[s][k])
        model.addConstr(constr_lhs, '<=', xi)
        
        # Set Gurobi MIP optimality gap
        if itr == 2:
            delta_i = min(0.03, g_i / 3)
        elif itr > 2:
            if delta_i_half_flag:
                delta_i /= 2.0
            delta_i = min(delta_i, 0.03)
            delta_i = min(delta_i, g_i / 3)
        gurobiMipGap = delta_i / (1 + delta_i)  # Gurobi_optimality_gap = (hi-lo)/hi, thus need conversion
        model.setParam("MIPGap", gurobiMipGap);
        
        # Update and solve model
        model.update()
        model.optimize()
        
        # Retrieve Gurobi outputs
        prev_a = [ [0] * locN for s in range(stageN) ]
        for s in range(stageN):
            for k in range(locN):
                prev_a[s][k] = model.getVarByName('a'+str(s)+','+str(k)).X
        MIP_solution = model.getVarByName('xi').X
        if MIP_solution > lo:
            lo = MIP_solution
            delta_i_half_flag = False
        else:
            delta_i_half_flag = True  # if lower bound does not change, halve delta_i in next iteration
        
        # Update total time
        total_time = time.time() - start_time
        
        # Compute relative optimality gap:
        if lo != 0.0:
            g_i = (hi - lo) / lo
        else:
            g_i = math.inf
        
        # Print debugging info
        if not hasSwap_relax_to_int_flag:
            if itr % 50 == 1:
                print("iter=%s, rela_gap=%.6f, hi=%.10f, lo=%.10f, delta_i=%.4e, time_taken=%.1f" \
                      % (itr, g_i, hi, lo, delta_i, total_time))
        else:
            print("iter=%s, rela_gap=%.6f, hi=%.10f, lo=%.10f, delta_i=%.4e, time_taken=%.1f" \
                  % (itr, g_i, hi, lo, delta_i, total_time))
        
        # Decide if terminates
        if hi - lo <= delta * lo:
            break
        
        itr += 1
        if total_time > 900:
            break
    optObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, optActionVec)
    return [optObjVal, optActionVec]

# %%
if runRoyset3:
    start_time_royset3 = time.time()
    [optObjVal_royset3, optActionVec_royset3] = \
        roysetSatoAlg3(agentN, locN, stageN, priorVec, tranProbMat, \
                       detectVec, missVec, delta=1e-10)
    time_elapsed_royset3 = time.time() - start_time_royset3

# %% [markdown]
# ## POMDP (Dynamic Programming)
#
# ### In paper "The Optimal Search for a Moving Target When the Search Path Is Constrained" by James N. Eagle

# %%
def eaglePomdp(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, isPrune=True): 
    actionVecSet= [[]]
    alphaVecSet = []
    alphaVecSet.append(np.zeros(locN))
    isPrintMiddleSteps = False
    for s in reversed(range(stageN)):
        print('\n---Stage ' + str(s) + '---\n')
        newActionVecSet = []
        newAlphaVecSet = []
        for i, alphaVec in enumerate(alphaVecSet):
            for action in getPossibleActions(locN, agentN):
                # update alpha vectors
                tmpAlphaVec = np.copy(alphaVec)
                identityMat = np.identity(locN)
                for k in range(locN):
                    identityMat[k, k] = missVec[k] ** action[k]
                newAlphaVec = identityMat.dot(tranProbMat.T).dot(tmpAlphaVec)
                extraVec = np.zeros(locN)
                for k in range(locN):
                    if action[k] > 0:
                        extraVec[k] = detectVec[k] ** action[k]
                newAlphaVec += extraVec
                newAlphaVecSet.append(newAlphaVec)
                # update associated actions
                newActionVec = list(actionVecSet[i])
                newActionVec.insert(0, action)
                newActionVecSet.append(newActionVec)        
        actionVecSet = newActionVecSet
        alphaVecSet = newAlphaVecSet
        # Prune dominated alpha vectors
        if isPrune:
            # Get indices of alpha vectors to be pruned
            pruneIndices = []
            for i in range(len(alphaVecSet)):
                alpha_i = alphaVecSet[i]
                for j in range(len(alphaVecSet)):
                    if j == i:
                        continue
                    alpha_j = alphaVecSet[j]
                    if functools.reduce(lambda x, y: x*y, np.less(alpha_i, alpha_j)):
                        pruneIndices.append(i)
                        break
            # Prune the dominated alpha vectors
            for i in sorted(pruneIndices, reverse=True):
                del alphaVecSet[i]
                del actionVecSet[i]
        if isPrintMiddleSteps:
            print('\nThe alpha vectors are:\n')
            print(alphaVecSet)
            print('\nThe actions are:\n')
            print(actionVecSet)
            print('\n')

    optObjVal = 0.0
    for i, alphaVec in enumerate(alphaVecSet):
        tmpObjVal = sum(np.multiply(alphaVec, priorVec))
        if tmpObjVal > optObjVal:
            optObjVal = tmpObjVal
            optActions = actionVecSet[i]
    optObjVal = 1 - optObjVal
    return [optObjVal, optActions]

# %%
if runDp:
    start_time_dp = time.time()
    [optObjVal_dp, optActions_dp] = eaglePomdp(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec, isPrune=True)
    time_elapsed_dp = time.time() - start_time_dp

# %% [markdown]
# ## Myopic Policy

# %%
def myopic(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec):
    # Alert: if use [[0]*locN]*stageN, then we have stageN lists referencing to the same list
    actionVec = [ [0] * locN for s in range(stageN) ] 

    # Initialize qR
    qR = np.empty([stageN,locN])
    qR[0,:] = priorVec
    
    # Same as forward recursion
    for s in range(stageN): 
        # Solve subproblem
        action = [0] * locN
        heap = []
        for k in range(locN):
            heapq.heappush(heap, (- qR[s,k] * detectVec[k], k))
        for m in range(agentN):
            ele = heapq.heappop(heap)
            action[ele[1]] += 1
            heapq.heappush(heap, (ele[0] * missVec[ele[1]], ele[1]))
        actionVec[s] = action
        # update qR
        if s < stageN - 1:
            tmp_q = np.copy(qR[s,:])  # must use np.copy, otherwise they reference the same array
            tmp_Is = np.power(missVec, actionVec[s])
            qR[s+1,:] = tranProbMat.dot(np.multiply(tmp_Is, tmp_q))
    optObjVal = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
    return [optObjVal, actionVec]

# %%
if runMyopic:
    start_time_myopic = time.time()
    [optObjVal_myopic, optActions_myopic] = myopic(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec)
    time_elapsed_myopic = time.time() - start_time_myopic

# %% [markdown]
# ## Brute Force

# %%
def bruteForce(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec):
    optObjVal = 1.0
    for actionVec in itertools.product(getPossibleActions(locN, agentN), repeat=stageN):
        tmp = computeObjVal(stageN, priorVec, tranProbMat, missVec, actionVec)
        if tmp < optObjVal:
            optObjVal = tmp
            optActionVec = actionVec
    return [optObjVal, optActionVec]

# %%
if runBrute:
    start_time_brute = time.time()
    [optObjVal_brute, optActionVec_brute] = bruteForce(agentN, locN, stageN, priorVec, tranProbMat, detectVec, missVec)
    time_elapsed_brute = time.time() - start_time_brute

# %% [markdown]
# ## Final Results

# %%
if runGetLowerBound:
    print('\n=====Lower Bound of Minimum=====\n')
    print('The lower bound of the minimum is ' + str(optLowerBound) + ' .\n')
    
if runOur_oneStage:
    print('\n=====For-Back Iter (With One Stage) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_our_oneStage) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_our_oneStage) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_our_oneStage) + ' .\n')
    print('The algorithm converges in ' + str(cycleN_our_oneStage) + ' cycles.\n')
    
if runOur_twoStage:
    print('\n=====For-Back Iter (With Two Stages) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_our_twoStage) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_our_twoStage) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_our_twoStage) + ' .\n')
    print('The algorithm converges in ' + str(cycleN_our_twoStage) + ' cycles.\n')
    
if runOur_oneStage_random:
    print('\n=====For-Back Iter Random (With One Stage) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_our_oneStage_random) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_our_oneStage_random) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_our_oneStage_random) + ' .\n')
    print('Random repetitions = ' + str(randomRepetitionN_our_oneStage_random) + ' .\n')
    
if runOur_twoStage_random:
    print('\n=====For-Back Iter Random (With Two Stages) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_our_twoStage_random) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_our_twoStage_random) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_our_twoStage_random) + ' .\n')
    print('Random repetitions = ' + str(randomRepetitionN_our_twoStage_random) + ' .\n')
    
if runRoyset2:
    print('\n=====Cutting-Plane (Royset-Sato Alg 2) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_royset2) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_royset2) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_royset2) + ' .\n')
    
if runRoyset3:
    print('\n=====Cutting-Plane (Royset-Sato Alg 3) Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_royset3) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_royset3) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_royset3) + ' .\n')
    
if runDp:
    print('\n=====POMDP Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_dp) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActions_dp) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_dp) + ' .\n')
    
if runMyopic:
    print('\n=====Myopic Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_myopic) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActions_myopic) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_myopic) + ' .\n')
    
if runBrute:
    print('\n=====Brute Force Final Results=====\n')
    print('The optimal objective value (prob of miss detection) is ' + str(optObjVal_brute) + ' .\n')
    if ifPrintPlan:
        print('\nThe optimal search plan is:\n\n' + str(optActionVec_brute) + '\n')
    print('Time taken to run is %.2f' % (time_elapsed_brute) + ' .\n')
# Out:
# =====Cutting-Plane (Royset-Sato Alg 2) Final Results=====
#
# The optimal objective value (prob of miss detection) is 0.859619406649 .
#
# Time taken to run is 271.62 .
